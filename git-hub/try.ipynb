# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Sanyam')

# %%
print('hello vikas')
# Out:
# hello vikas

# %%
print('Khevansh yadav')
# Out:
# Khevansh yadav

# %%
from sklearn.datasets import load_iris
